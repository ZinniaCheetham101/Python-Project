# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
#Import Data
path= r'C:\Users\Zinnia\Documents\Career Foundry Data Analytics Course\Achievement 4\A4 Project\Data1\Original Data'
df_ords=pd.read_csv(os.path.join(path,'orders.csv'), index_col=False)
df_prods=pd.read_csv(os.path.join(path,'products.csv'), index_col=False)

# %%
#Drop unnecessary column
df_ords.drop(columns= ['eval_set'])
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
# Count NaN values in the days_since_prior_order column
df_ords['days_since_prior_order'].value_counts(dropna = False)
# Out:
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: days_since_prior_order, dtype: int64

# %%
#Renaming day of the week columns
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)
df_ords.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2398795        1    prior             2                   3
# 2    473747        1    prior             3                   3
# 3   2254736        1    prior             4                   4
# 4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
#Changing data type for order id from a number to a string/object using the singular dtype and check the data type
df_ords['order_id'] = df_ords['order_id'].astype('str')
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
# Import departments
df_dep=pd.read_csv(os.path.join(path,'departments.csv'), index_col=False)

# %%
df_dep.head()
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transpose the table
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
#Transposing by overwriting
df_dep_t = df_dep.T

# %%
#Creating an index
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
#Create a new header
new_header = df_dep_t.iloc[0]

# %%
#New dataframe with all data except first row
df_dep_t_new = df_dep_t[1:]

# %%
#Redefine columns to rename our header
df_dep_t_new.columns = new_header

# %%
#Create data dictionary from dep_t_new dataframe
data_dict = df_dep_t_new.to_dict('index')

# %%
#Subsetting
df_snacks =  df_prods[df_prods['department_id']==19]

# %%
#Find another identifier variable in the df_ords dataframe that doesn’t need to be included in your analysis as a numeric variable and change it to a suitable format.
df_ords['user_id'] = df_ords['user_id'].astype('str')

# %%
# Look for a variable in your df_ords dataframe with an unintuitive name and change its name without overwriting the data frame
df_new = df_ords.rename(columns = {'order_hour_of_day' : 'orders_time'}, inplace = False)

# %%
df_new.head()
# Out:
#   order_id user_id eval_set  order_number  orders_day_of_week  orders_time  \
# 0  2539329       1    prior             1                   2            8
# 1  2398795       1    prior             2                   3            7
# 2   473747       1    prior             3                   3           12
# 3  2254736       1    prior             4                   4            7
# 4   431534       1    prior             5                   4           15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Your client wants to know what the busiest hour is for placing orders. Find the frequency of the corresponding variable and share your findings.
df_ords['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    288418
# 11    284728
# 15    283639
# 14    283042
# 13    277999
# 12    272841
# 16    272553
# 9     257812
# 17    228795
# 18    182912
# 8     178201
# 19    140569
# 20    104292
# 7      91868
# 21     78109
# 22     61468
# 23     40043
# 6      30529
# 0      22758
# 1      12398
# 5       9569
# 2       7539
# 4       5527
# 3       5474
# Name: order_hour_of_day, dtype: int64

# %%
#Determine the meaning behind a value of 4 in the "department_id" column
print(data_dict.get('4'))
# Out:
# {'department': 'produce'}

# %%
#The sales team in your client’s organization wants to know more about breakfast item sales. 
df_breakfast =  df_prods[df_prods['department_id']==14]

# %%
df_breakfast.head()
# Out:
#      product_id                                      product_name  aisle_id  \
# 27           28                                 Wheat Chex Cereal       121
# 33           34                                               NaN       121
# 67           68                           Pancake Mix, Buttermilk       130
# 89           90                                      Smorz Cereal       121
# 210         211  Gluten Free Organic Cereal Coconut Maple Vanilla       130
#
#      department_id  prices
# 27              14    10.1
# 33              14    12.2
# 67              14    13.7
# 89              14     3.9
# 210             14     3.6

# %%
#find all observations from the entire dataframe that include items from the following  departments: alcohol, deli, beverages, and meat/seafood
df_dinner_party = df_prods.loc[df_prods['department_id'].isin([5,20,7,12])]
df_dinner_party.head(30)
# Out:
#      product_id                                       product_name  aisle_id  \
# 2             3               Robust Golden Unsweetened Oolong Tea        94
# 6             7                     Pure Coconut Water With Orange        98
# 9            10     Sparkling Orange Juice & Prickly Pear Beverage       115
# 10           11                                  Peach Mango Juice        31
# 16           17                                  Rendered Duck Fat        35
# 19           20     Pomegranate Cranberry & Aloe Vera Enrich Drink        98
# 22           23                             Organic Turkey Burgers        49
# 34           35     Italian Herb Porcini Mushrooms Chicken Sausage       106
# 38           39           Daily Tangerine Citrus Flavored Beverage        64
# 39           40  Beef Hot Links Beef Smoked Sausage With Chile ...       106
# 43           44                        Sparkling Raspberry Seltzer       115
# ...

# %%
#How many rows does the last dataframe you created have?
df_dinner_party.shape
# Out:
# (7650, 5)

# %%
#Extract all the information you can about df_user_1
df_user_1 = df_ords[df_ords['user_id']=='1']

# %%
df_user_1.head(30)
# Out:
#    order_id user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329       1    prior             1                   2
# 1   2398795       1    prior             2                   3
# 2    473747       1    prior             3                   3
# 3   2254736       1    prior             4                   4
# 4    431534       1    prior             5                   4
# 5   3367565       1    prior             6                   2
# 6    550135       1    prior             7                   1
# 7   3108588       1    prior             8                   1
# 8   2295261       1    prior             9                   1
# 9   2550362       1    prior            10                   4
# 10  1187899       1    train            11                   4
#
#     order_hour_of_day  days_since_prior_order
# 0                   8                     NaN
# 1                   7                    15.0
# 2                  12                    21.0
# ...

# %%
df_user_1.describe()
# Out:
#        order_number  orders_day_of_week  order_hour_of_day  \
# count     11.000000           11.000000          11.000000
# mean       6.000000            2.636364          10.090909
# std        3.316625            1.286291           3.477198
# min        1.000000            1.000000           7.000000
# 25%        3.500000            1.500000           7.500000
# 50%        6.000000            3.000000           8.000000
# 75%        8.500000            4.000000          13.000000
# max       11.000000            4.000000          16.000000
#
#        days_since_prior_order
# count               10.000000
# mean                19.000000
# std                  9.030811
# min                  0.000000
# 25%                 14.250000
# 50%                 19.500000
# 75%                 26.250000
# max                 30.000000

# %%
# 12. Export your df_ords dataframe as “orders_wrangled.csv” in your “Prepared Data” folder.
df_ords.to_csv((r'C:\Users\Zinnia\Documents\Career Foundry Data Analytics Course\Achievement 4\A4 Project\Data1\Prepared Data\orders_wrangled.csv'))
